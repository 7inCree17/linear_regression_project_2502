# %% [markdown]
# <a href="https://colab.research.google.com/github/7inCree17/linear_regression_project_2502/blob/master/Analayjins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#camera_image => df4
df4 = pd.read_parquet("/content/sample_data/training_stats_10023947602400723454_1120_000_1140_000.parquet",engine='pyarrow')
print(df4.shape, df4.dtypes)
print(df4.head())
print(df4.info())
# Out:
# (199, 9) key.segment_context_name                        object
# key.frame_timestamp_micros                       int64
# [StatsComponent].time_of_day                    object
# [StatsComponent].location                       object
# [StatsComponent].weather                        object
# [StatsComponent].lidar_object_counts.types      object
# [StatsComponent].lidar_object_counts.counts     object
# [StatsComponent].camera_object_counts.types     object
# [StatsComponent].camera_object_counts.counts    object
# dtype: object
#                                                                   key.segment_context_name  \
# index
# 10023947602400723454_1120_000_1140_000;15524401...  10023947602400723454_1120_000_1140_000
# 10023947602400723454_1120_000_1140_000;15524401...  10023947602400723454_1120_000_1140_000
# 10023947602400723454_1120_000_1140_000;15524401...  10023947602400723454_1120_000_1140_000
# ...

# %%
import pandas as pd

#camera_image => df4
df4 = pd.read_parquet("/content/sample_data/training_camera_hkp_10023947602400723454_1120_000_1140_000.parquet",engine='pyarrow')
print(df4.shape, df4.dtypes)
print(df4.head())
# Out:
# (497, 12) key.segment_context_name                                                                  object
# key.frame_timestamp_micros                                                                 int64
# key.camera_name                                                                             int8
# key.camera_object_id                                                                      object
# [CameraHumanKeypointsComponent].camera_keypoints[*].type                                  object
# [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.x             object
# [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.y             object
# [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.visibility.is_occluded    object
# [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.x              object
# [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.y              object
# ...
